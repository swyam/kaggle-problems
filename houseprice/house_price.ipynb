# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
ls
# Out:
# gdrive/  sample_data/

# %%
cd /content/gdrive/My\ Drive/Colab Notebooks/kaggle/houseprice
# Out:
# /content/gdrive/My Drive/Colab Notebooks/kaggle/houseprice

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from keras.utils import to_categorical
from keras import models
from keras import layers
from sklearn.model_selection import train_test_split

from keras.models import Sequential
from keras.layers import Activation
from keras.optimizers import SGD
from keras.layers import Dense
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
import pandas as pd
file1=pd.read_csv("sample_submission.csv") 

file3=pd.read_csv("test.csv", keep_default_na=False)
#file2
# Out:
#         Id  MSSubClass MSZoning LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL          65     8450   Pave    NA      Reg
# 1        2          20       RL          80     9600   Pave    NA      Reg
# 2        3          60       RL          68    11250   Pave    NA      IR1
# 3        4          70       RL          60     9550   Pave    NA      IR1
# 4        5          60       RL          84    14260   Pave    NA      IR1
# 5        6          50       RL          85    14115   Pave    NA      IR1
# 6        7          20       RL          75    10084   Pave    NA      Reg
# 7        8          60       RL          NA    10382   Pave    NA      IR1
# 8        9          50       RM          51     6120   Pave    NA      Reg
# 9       10         190       RL          50     7420   Pave    NA      Reg
# 10      11          20       RL          70    11200   Pave    NA      Reg
# ...

# %%
#df=file2.drop(columns=['PassengerId','Name','Ticket','Cabin'])

d1={'WD':1,'CWD':2,'VWD':3,'New':4,'COD':5,'Con':6,'ConLw':7,'ConLI':8,'ConLD':9,'Oth':10}
d2={'Normal':1,'Abnorml':2,'AdjLand':3,'Alloca':4,'Family':5,'Partial':6}
d3={'Elev':1,'Gar2':2,'Othr':3,'Shed':4,'TenC':5,'NA':6}
d4={'GdPrv':1,'MnPrv':2,'GdWo':3,'MnWw':4,'NA':5}
d5={'Ex':1,'Gd':2,'TA':3,'Fa':4,'NA':5}
d6={'Y':1,'P':2,'N':3}
d7={'Ex':1,'Gd':2,'TA':3,'Fa':4,'Po':5,'NA':6}
d8={'Fin':1,'RFn':2,'Unf':3,'NA':4}
d9={'Attchd':1,'Basment':2,'BuiltIn':3,'CarPort':4,'Detchd':5,'NA':6,'2Types':7}
d10={'Typ':1,'Min1':2,'Min2':3 ,'Mod':4,'Maj1':5 ,'Maj2':6,'Sev':7,'Sal':8}
d11={'SBrkr':1,'FuseA':2 ,'FuseF':3 ,'FuseP':4,'Mix':5}
d12={'Y':1,'N':2}
d13={'Floor':1,'GasA':2,'GasW':3,'Grav':4,'OthW':5,'Wall':6}
d14={'GLQ':1,'ALQ':2,'BLQ':3,'Rec':4 ,'LwQ':5,'Unf':6,'NA':7}
d15={'Gd':1,'Av':2,'Mn':3,'No':4,'NA':5}
d16={'BrkTil':1,'CBlock':2 ,'PConc':3,'Slab':4,'Stone':5,'Wood':6}
d17={'BrkCmn':1,'BrkFace':2 ,'CBlock':3,'None':4,'Stone':5 }
d18={'AsbShng':1,'AsphShn':2,'BrkComm':3,'BrkFace':4,'CBlock':5 ,'CemntBd':6,'HdBoard':7 ,'ImStucc':8 ,'MetalSd':9,'Other':10 ,'Plywood':11,'PreCast':12,'Stone':13,'Stucco':14 ,'VinylSd':15,'Wd Sdng':16,'WdShing':17}
d19={ 'ClyTile':1 ,'CompShg':2, ,'Membran':3,'Metal':4,'Roll':5,'Tar&Grv':6,'WdShake':7 ,'WdShngl':8 }
d20={  'Flat':1,'Gable':2 ,'Gambrel':3 ,'Hip':4 ,'Mansard':5,'Shed':6 }
d21={ '1Story':1 ,'1.5Fin':2  ,'1.5Unf':3,'2Story':4 ,'2.5Fin':5 ,'2.5Unf':6 ,'SFoyer':7,'SLvl':8}



#print(d1)
file2=pd.read_csv("train.csv", keep_default_na=False)
file2.dtypes
file2['SaleType'].replace(d1, inplace=True)
file2['SaleCondition'].replace(d2, inplace=True)
file2['MiscFeature'].replace(d3, inplace=True)
file2['Fence'].replace(d4, inplace=True)
file2['PoolQC'].replace(d5, inplace=True)
file2['PavedDrive'].replace(d6, inplace=True)
file2['GarageCond'].replace(d7, inplace=True)
file2['GarageQual'].replace(d7, inplace=True)
file2['GarageFinish'].replace(d8, inplace=True)
file2['GarageType'].replace(d9, inplace=True)
file2['FireplaceQu'].replace(d7, inplace=True)
file2['Functional'].replace(d10, inplace=True)

file2['KitchenQual'].replace(d7, inplace=True)
file2['Electrical'].replace(d11, inplace=True)
file2['CentralAir'].replace(d12, inplace=True)
file2['HeatingQC'].replace(d7, inplace=True)

file2['BsmtFinType2'].replace(d14, inplace=True)
file2['Heating'].replace(d13, inplace=True)
file2['BsmtFinType1'].replace(d14, inplace=True)
file2['BsmtExposure'].replace(d15, inplace=True)
file2['BsmtCond'].replace(d7, inplace=True)
file2['BsmtQual'].replace(d7, inplace=True)
file2['Foundation'].replace(d16, inplace=True)
file2['ExterCond'].replace(d7, inplace=True)

file2['ExterQual'].replace(d7, inplace=True)
file2['MasVnrType'].replace(d17, inplace=True)
file2['Exterior2nd'].replace(d18, inplace=True)
file2['Exterior1st'].replace(d18, inplace=True)
file2['RoofMatl'].replace(d19, inplace=True)


file2['RoofStyle'].replace(d20, inplace=True)
file2['HouseStyle'].replace(d21, inplace=True)
file2['Exterior2nd'].replace(d18, inplace=True)
file2['Exterior1st'].replace(d18, inplace=True)
file2['RoofMatl'].replace(d19, inplace=True)



(file2)


#X=df.values

#y=y.values


#y


#df.replace

#df.values
#df = pd.DataFrame(file1, columns=['Survived'])
# Out:
#         Id  MSSubClass MSZoning LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL          65     8450   Pave    NA      Reg
# 1        2          20       RL          80     9600   Pave    NA      Reg
# 2        3          60       RL          68    11250   Pave    NA      IR1
# 3        4          70       RL          60     9550   Pave    NA      IR1
# 4        5          60       RL          84    14260   Pave    NA      IR1
# 5        6          50       RL          85    14115   Pave    NA      IR1
# 6        7          20       RL          75    10084   Pave    NA      Reg
# 7        8          60       RL          NA    10382   Pave    NA      IR1
# 8        9          50       RM          51     6120   Pave    NA      Reg
# 9       10         190       RL          50     7420   Pave    NA      Reg
# 10      11          20       RL          70    11200   Pave    NA      Reg
# ...

# %%
df=file3.drop(columns=['Name','Ticket','Cabin'])
df=df.fillna(df['Age'].mean())
df=df.replace('male',1)
df=df.replace('female',2)
df=df.replace('S',1)
df=df.replace('C',2)
df=df.replace('Q',2)
y_id=df['PassengerId']
df=df.drop(columns=['PassengerId'])
X_test=df.values
X_test
df=file1[:891]
print(df)

y_act=df['Survived']
y_act=y_act.values
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# 5            897         0
# 6            898         1
# 7            899         0
# 8            900         1
# 9            901         0
# 10           902         0
# 11           903         0
# 12           904         1
# 13           905         0
# 14           906         1
# 15           907         1
# 16           908         0
# 17           909         0
# 18           910         1
# 19           911         1
# 20           912         0
# 21           913         0
# 22           914         1
# 23           915         0
# 24           916         1
# 25           917         0
# 26           918         1
# 27           919         0
# 28           920         0
# 29           921         0
# ..           ...       ...
# 388         1280         0
# 389         1281         0
# ...

# %%
print(X.shape)
print(y.shape)
from sklearn.svm import SVC
clf = SVC(gamma='auto')
clf.fit(X, y)  
#x_test[0]
predicted=clf.predict(X_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_act, predicted)
# Out:
# (891, 7)
# (891,)
# 0.6794258373205742

# %%
from sklearn import naive_bayes
classifier = naive_bayes.GaussianNB()
model = classifier.fit(X,y)
prediction = model.predict(X_test)
accuracy_score(y_act, prediction)
# Out:
# 0.8301435406698564

# %%
import xgboost as xgb
clf = xgb.XGBClassifier(objective="binary:logistic", random_state=42)
clf = clf.fit(X, y)
prediction__ = clf.predict(X_test)
app=prediction__.tolist()
df1 = pd.DataFrame({'Survived':app})
#print(df1)
df__=df['PassengerId']
df__=df__.values
df__=df__.tolist()
#print(df__)
df2 = pd.DataFrame({'PassengerId':df__})
df_ = pd.concat([df2, df1],axis=1)
export_csv=df_.to_csv('file1.csv',index=False)
print(df_)
accuracy_score(y_act, prediction__)
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         0
# 5            897         0
# 6            898         1
# 7            899         0
# 8            900         1
# 9            901         0
# 10           902         0
# 11           903         0
# 12           904         1
# 13           905         0
# 14           906         1
# 15           907         1
# 16           908         0
# 17           909         0
# 18           910         0
# 19           911         0
# 20           912         0
# 21           913         1
# 22           914         1
# 23           915         0
# 24           916         1
# 25           917         0
# 26           918         1
# 27           919         0
# 28           920         1
# 29           921         0
# ..           ...       ...
# 388         1280         0
# 389         1281         0
# ...

# %%
from sklearn.neural_network import MLPClassifier
clf=MLPClassifier(solver='lbfgs', alpha=1e-5,hidden_layer_sizes=(16,4), random_state=1)
clf.fit(X, y)
prediction_ = clf.predict(X_test)
app=prediction_.tolist()
df1 = pd.DataFrame({'Survived':app})
#print(df1)
df__=df['PassengerId']
df__=df__.values
df__=df__.tolist()
#print(df__)
df2 = pd.DataFrame({'PassengerId':df__})
df_ = pd.concat([df2, df1],axis=1)
df_.to_csv('file3.csv',index=False)
#print(df_)

accuracy_score(y_act, prediction_)
# Out:
# 0.6363636363636364

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=65, max_depth=3,random_state=0)
#print(y.shape)
clf.fit(X, y)
prediction_ = clf.predict(X_test)
app=prediction_.tolist()
df1 = pd.DataFrame({'Survived':app})
#print(df1)
df__=df['PassengerId']
df__=df__.values
df__=df__.tolist()
#print(df__)
df2 = pd.DataFrame({'PassengerId':df__})
df_ = pd.concat([df2, df1],axis=1)
df_.to_csv('file.csv',index=False)
#print(df_)

accuracy_score(y_act, prediction_)
# Out:
# 0.9234449760765551
